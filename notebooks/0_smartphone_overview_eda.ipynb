# %% [markdown]
# # Import Libraries

# %%
import os

import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

import missingno as msno

from pathlib import Path

from src.utils.utils import get_data, outlier_overview, export_data, prepare_segment_trends_data

# %%
# Set the maximum number of columns to display
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read the Data

# %%
df = get_data("smartphone_cleaned_v5", "raw")
df.sample(50)
# Out:
#     brand_name                                             model   price  \
# 949    oneplus                                         OnePlus Z   24999
# 41      xiaomi                  Xiaomi Redmi Note 11 Pro Plus 5G   19999
# 388       oppo                                          OPPO F19   14990
# 925   micromax                   Micromax IN 2B (6GB RAM + 64GB)    7790
# 178       vivo                       Vivo V25 (12GB RAM + 256GB)   31999
# 227     realme                                  Realme GT Neo 3T   24999
# 676    infinix                              Infinix Smart 6 Plus    8299
# 67      xiaomi  Xiaomi Redmi Note 12 Pro Plus (12GB RAM + 256GB)   32999
# 570       oppo                       OPPO A77 (4GB RAM + 128 GB)   15998
# 339     xiaomi                              Xiaomi Redmi 9 Activ    7499
# 29     oneplus                                    OnePlus 11 Pro   69999
# 973     google                                Google Pixel 8 Pro   70990
# 440   motorola                                 Motorola Moto G13   15999
# 164    samsung                                Samsung Galaxy F13   10999
# 951     huawei                  Huawei Mate 30 RS Porsche Design  214990
# 289    samsung                                Samsung Galaxy M13   12999
# 379       vivo                                         Vivo Y02s    8990
# 699       asus                        Asus ROG Phone 6D Ultimate  107990
# 568       oppo                                      OPPO Reno 10   32999
# 675      honor                                     Honor Play 30    9999
# 102   motorola                             Motorola Moto S30 Pro   23990
# 472       vivo                                          Vivo Y25    7499
# 840    samsung                             Samsung Galaxy S10 5G   78990
# 892      apple                              Apple iPhone 15 Plus   84990
# 806     xiaomi                     Xiaomi Redmi 10 Prime Plus 5G   13990
# 86     samsung                             Samsung Galaxy A23 5G   22999
# 564       vivo                                          Vivo Y71   25000
# 875    samsung    Samsung Galaxy S21 Ultra 5G (12GB RAM + 128GB)  101999
# 473        lyf                                       Lyf Earth 1    3990
# 231       vivo                                       Vivo T1x 4G   11999
# 843     doogee                                      Doogee V Max   45999
# 318       iqoo                        iQOO 11 (16GB RAM + 256GB)   64999
# 624    oneplus                            OnePlus Nord 2 Lite 5G   22999
# 896       oppo               OPPO Reno 8 House of Dragon Edition   32990
# 407       oppo                                       Oppo A77 5G   21990
# 962     doogee                                        Doogee S99   14999
# 804    samsung                                Samsung Galaxy M14   14999
# 328       vivo                        Vivo T1x (6GB RAM + 128GB)   14999
# 378    samsung                                Samsung Galaxy A71   22494
# 793    oneplus                                 OnePlus Nord N300   18990
# 181      tecno                               Tecno Spark Go 2023    6999
# 569      nokia                                         Nokia G60   28498
# 160       cola                                        Cola Phone   14999
# 758       vivo                                         Vivo V23e   26990
# 169       letv                                       Letv Y1 Pro    5499
# 61        vivo                                          Vivo S16   29990
# 291     xiaomi           Xiaomi Redmi Note 10S (8GB RAM + 128GB)   13999
# 671       poco                                       Poco M6 Pro   19990
# 447       vivo                                       Vivo X80 5G   54999
# 812     xiaomi       Xiaomi Redmi Note 10 Lite (4GB RAM + 128GB)   12499
#
#      rating  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 949    79.0   False    False           False      snapdragon        8.0
# 41     83.0    True    False            True      snapdragon        8.0
# 388    78.0   False    False           False      snapdragon        8.0
# 925    68.0   False    False           False          unisoc        8.0
# 178    85.0    True    False           False       dimensity        8.0
# 227    79.0    True    False           False      snapdragon        8.0
# 676    63.0   False    False           False           helio        8.0
# 67     87.0    True    False            True       dimensity        8.0
# 570    71.0   False    False           False           helio        8.0
# 339    68.0   False    False           False           helio        8.0
# 29      NaN    True     True           False      snapdragon        8.0
# 973    80.0    True     True           False          google        8.0
# 440    75.0   False     True           False           helio        8.0
# 164    74.0   False     True           False          exynos        8.0
# 951     NaN    True     True            True           kirin        8.0
# 289    75.0   False    False           False          exynos        8.0
# 379    61.0   False    False           False           helio        8.0
# 699     NaN    True     True           False       dimensity        8.0
# 568    84.0    True     True           False      snapdragon        8.0
# 675    68.0    True    False           False      snapdragon        8.0
# 102    83.0    True    False           False      snapdragon        8.0
# 472     NaN   False    False           False           helio        4.0
# 840    86.0    True     True           False          exynos        8.0
# 892    75.0    True     True           False          bionic        6.0
# 806    69.0    True    False            True       dimensity        8.0
# 86     79.0    True    False           False      snapdragon        8.0
# 564     NaN   False    False           False      snapdragon        4.0
# 875     NaN    True     True           False          exynos        8.0
# 473    60.0   False    False           False      snapdragon        8.0
# 231    74.0   False    False           False      snapdragon        8.0
# 843    88.0    True    False           False       dimensity        8.0
# 318    89.0    True     True           False      snapdragon        8.0
# 624    83.0    True     True           False      snapdragon        8.0
# 896    84.0    True     True           False       dimensity        8.0
# 407    76.0    True    False           False      snapdragon        8.0
# 962    84.0   False     True           False           helio        8.0
# 804    60.0   False    False           False          exynos        8.0
# 328    77.0   False    False           False      snapdragon        8.0
# 378    86.0   False    False           False      snapdragon        8.0
# 793    75.0    True     True           False       dimensity        8.0
# 181    62.0   False    False           False           helio        4.0
# 569    81.0    True     True           False      snapdragon        8.0
# 160    74.0   False    False           False           helio        8.0
# 758    82.0   False    False           False           helio        8.0
# 169     NaN   False    False           False           tiger        4.0
# 61     85.0    True     True           False      snapdragon        8.0
# 291    82.0   False    False            True           helio        8.0
# 671    84.0    True    False            True       dimensity        8.0
# 447    86.0    True    False           False       dimensity        8.0
# 812    77.0   False    False            True      snapdragon        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 949             2.40            4300.0                        1
# 41              2.20            5000.0                        1
# 388             2.00            5000.0                        1
# 925             1.80            5000.0                        0
# 178             2.00            4500.0                        1
# 227             3.20            5000.0                        1
# 676             2.00            5000.0                        0
# 67              2.60            4980.0                        1
# 570             2.30            5000.0                        1
# 339             2.30            5000.0                        0
# 29              3.20            4500.0                        1
# 973              NaN            5000.0                        1
# 440             2.00            5000.0                        1
# 164             2.00            6000.0                        1
# 951             2.86            4500.0                        1
# 289             2.00            6000.0                        1
# 379             2.30            5000.0                        1
# 699             3.20            6000.0                        1
# 568             2.50            5000.0                        1
# 675             2.20            5000.0                        0
# 102             2.90            4400.0                        1
# 472             1.30            1900.0                        0
# 840             2.70            4500.0                        1
# 892              NaN            4532.0                        1
# 806             2.20            5000.0                        1
# 86              2.20            5000.0                        1
# 564             1.40            3360.0                        0
# 875             2.90            5000.0                        1
# 473             1.50            3500.0                        0
# 231             2.40            5000.0                        1
# 843             2.60           22000.0                        1
# 318             3.20            5000.0                        1
# 624             2.20            5000.0                        1
# 896             3.00            4500.0                        1
# 407             2.40            5000.0                        1
# 962             2.05            6000.0                        1
# 804              NaN            6000.0                        0
# 328             2.40            5000.0                        1
# 378             2.20            4500.0                        1
# 793             2.40            5000.0                        1
# 181             2.00            5000.0                        1
# 569             2.20            4500.0                        1
# 160             2.20            5000.0                        1
# 758             2.05            4050.0                        1
# 169             2.00            4000.0                        0
# 61              3.20            4600.0                        1
# 291             2.05            5000.0                        1
# 671             2.50            5100.0                        1
# 447             3.05            4500.0                        1
# 812             2.30            5020.0                        1
#
#      fast_charging  ram_capacity  internal_memory  screen_size  refresh_rate  \
# 949           30.0           8.0            128.0         6.55            90
# 41            67.0           6.0            128.0         6.67           120
# 388           33.0           6.0            128.0         6.40            60
# 925            NaN           6.0             64.0         6.52            60
# 178           44.0          12.0            256.0         6.44            90
# 227           80.0           6.0            128.0         6.62           120
# 676            NaN           3.0             64.0         6.82            60
# 67           120.0          12.0            256.0         6.67           120
# 570           33.0           4.0            128.0         6.56            60
# 339            NaN           4.0             64.0         6.53            60
# 29           100.0           8.0            128.0         6.70           120
# 973           67.0          12.0            256.0         6.73           120
# 440           10.0           4.0            128.0         6.50            90
# 164           15.0           4.0             64.0         6.60            60
# 951            NaN          12.0            512.0         6.53            60
# 289           15.0           6.0            128.0         6.60            60
# 379           10.0           3.0             32.0         6.51            60
# 699           65.0          16.0            512.0         6.78           165
# 568          120.0           8.0            256.0         6.73           120
# 675            NaN           4.0            128.0         6.50            60
# 102           68.0           8.0            128.0         6.55           144
# 472            NaN           1.0             16.0         4.50            60
# 840           25.0           8.0            256.0         6.70            60
# 892            NaN           8.0            128.0         6.71           120
# 806           18.0           4.0            128.0         6.58            90
# 86            25.0           6.0            128.0         6.60           120
# 564            NaN           3.0             16.0         6.00            60
# 875           25.0          12.0            128.0         6.80           120
# 473            NaN           3.0             32.0         5.50            60
# 231           18.0           4.0             64.0         6.58            90
# 843           33.0          12.0            256.0         6.58           120
# 318          120.0          16.0            256.0         6.78           144
# 624           33.0           8.0            128.0         6.59           120
# 896           80.0           8.0            128.0         6.43            90
# 407           33.0           6.0            128.0         6.56            90
# 962           33.0           8.0            128.0         6.30            60
# 804            NaN           4.0             64.0         6.50            60
# 328           18.0           6.0            128.0         6.58            90
# 378           25.0           8.0            128.0         6.70            60
# 793           33.0           4.0             64.0         6.56            90
# 181           10.0           3.0             32.0         6.56            60
# 569           20.0           6.0            128.0         6.58           120
# 160           33.0           4.0             64.0         6.40            90
# 758           44.0           8.0            128.0         6.44            60
# 169            NaN           4.0             32.0         6.54            60
# 61            66.0           8.0            128.0         6.78           120
# 291           33.0           8.0            128.0         6.43            60
# 671          120.0           8.0            128.0         6.73           120
# 447           80.0           8.0            128.0         6.78           120
# 812           18.0           4.0            128.0         6.67            60
#
#        resolution  num_rear_cameras  num_front_cameras       os  \
# 949  1080 x 2400                  3                1.0  android
# 41   1080 x 2400                  3                1.0  android
# 388  1080 x 2400                  3                1.0  android
# 925   720 x 1600                  2                1.0  android
# 178  1080 x 2408                  3                1.0  android
# 227  1080 x 2400                  3                1.0  android
# 676   720 x 1600                  2                1.0  android
# 67   1080 x 2400                  3                1.0  android
# 570   720 x 1600                  2                1.0  android
# 339   720 x 1600                  2                1.0  android
# 29   1440 x 3216                  3                1.0  android
# 973  1440 x 3120                  3                1.0  android
# 440   720 x 1600                  3                1.0  android
# 164  2408 x 1080                  3                1.0  android
# 951  1176 x 2400                  4                2.0  android
# 289  1080 x 2400                  3                1.0  android
# 379   720 x 1600                  1                1.0  android
# 699  1080 x 2448                  3                1.0      NaN
# 568  1080 x 2412                  3                1.0  android
# 675   720 x 1600                  1                1.0  android
# 102  1080 x 2460                  3                1.0  android
# 472    480 x 854                  1                1.0  android
# 840  1440 x 3040                  3                1.0  android
# 892  1284 x 2778                  2                1.0      ios
# 806  1080 x 2408                  2                1.0  android
# 86   1080 x 2408                  4                1.0  android
# 564   720 x 1440                  1                1.0  android
# 875  1440 x 3200                  4                1.0  android
# 473  1080 x 1920                  2                1.0  android
# 231  1080 x 2408                  2                1.0  android
# 843  1080 x 2408                  3                1.0  android
# 318  1440 x 3200                  3                1.0  android
# 624  1080 x 2412                  3                1.0  android
# 896  1080 x 2400                  3                1.0  android
# 407   720 x 1600                  2                1.0  android
# 962  1080 x 2340                  3                1.0  android
# 804   720 x 1600                  3                1.0  android
# 328  1080 x 2408                  2                1.0  android
# 378  1080 x 2400                  4                1.0  android
# 793   720 x 1612                  2                1.0  android
# 181   720 x 1600                  2                1.0  android
# 569  1080 x 2400                  3                1.0  android
# 160  1080 x 2400                  2                1.0  android
# 758  1080 x 2400                  3                1.0  android
# 169   720 x 1560                  2                1.0  android
# 61   1080 x 2400                  3                1.0  android
# 291  1080 x 2400                  4                1.0  android
# 671  1080 x 2400                  3                1.0  android
# 447  1080 x 2400                  3                1.0  android
# 812  1080 x 2400                  4                1.0  android
#
#      primary_camera_rear  primary_camera_front  extended_memory_available  \
# 949                 64.0                  16.0                          0
# 41                 108.0                  16.0                          1
# 388                 48.0                  16.0                          1
# 925                 13.0                   5.0                          1
# 178                 64.0                  50.0                          1
# 227                 64.0                  16.0                          0
# 676                  8.0                   5.0                          1
# 67                 200.0                  16.0                          0
# 570                 50.0                   8.0                          1
# 339                 13.0                   5.0                          1
# 29                  50.0                  16.0                          0
# 973                 50.0                  12.0                          0
# 440                 50.0                   8.0                          1
# 164                 50.0                   8.0                          1
# 951                 40.0                  32.0                          1
# 289                 50.0                   8.0                          1
# 379                  8.0                   5.0                          1
# 699                 50.0                  12.0                          0
# 568                 50.0                  32.0                          0
# 675                 13.0                   5.0                          1
# 102                 50.0                  32.0                          0
# 472                  5.0                   2.0                          1
# 840                 16.0                  10.0                          1
# 892                 12.0                  12.0                          0
# 806                 50.0                   5.0                          0
# 86                  50.0                   8.0                          1
# 564                 13.0                   5.0                          1
# 875                108.0                  40.0                          0
# 473                 13.0                   5.0                          1
# 231                 50.0                   8.0                          1
# 843                108.0                  32.0                          1
# 318                 50.0                  16.0                          0
# 624                 64.0                  16.0                          1
# 896                 50.0                  32.0                          0
# 407                 48.0                   8.0                          1
# 962                108.0                  32.0                          1
# 804                 48.0                   8.0                          1
# 328                 50.0                   8.0                          1
# 378                 64.0                  32.0                          1
# 793                 48.0                  16.0                          1
# 181                 13.0                   5.0                          1
# 569                 50.0                   8.0                          1
# 160                 50.0                  16.0                          1
# 758                 64.0                  50.0                          0
# 169                  8.0                   5.0                          0
# 61                  64.0                  50.0                          0
# 291                 64.0                  13.0                          1
# 671                108.0                  32.0                          1
# 447                 50.0                  32.0                          0
# 812                 48.0                  16.0                          1
#
#      extended_upto
# 949            NaN
# 41          1024.0
# 388          256.0
# 925          256.0
# 178         1024.0
# 227            NaN
# 676          512.0
# 67             NaN
# 570            NaN
# 339          512.0
# 29             NaN
# 973            NaN
# 440          512.0
# 164         1024.0
# 951          256.0
# 289         1024.0
# 379            NaN
# 699            NaN
# 568            NaN
# 675            NaN
# 102            NaN
# 472          128.0
# 840          512.0
# 892            NaN
# 806            NaN
# 86          1024.0
# 564            NaN
# 875            NaN
# 473           64.0
# 231            NaN
# 843         2048.0
# 318            NaN
# 624            NaN
# 896            NaN
# 407            NaN
# 962         1024.0
# 804          512.0
# 328            NaN
# 378         1024.0
# 793            NaN
# 181          256.0
# 569            NaN
# 160         1024.0
# 758            NaN
# 169            NaN
# 61             NaN
# 291          512.0
# 671         1024.0
# 447            NaN
# 812          512.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
#  13  ram_capacity               980 non-null    float64
#  14  internal_memory            980 non-null    float64
#  15  screen_size                980 non-null    float64
#  16  refresh_rate               980 non-null    int64
#  17  resolution                 980 non-null    object
#  18  num_rear_cameras           980 non-null    int64
#  19  num_front_cameras          976 non-null    float64
#  20  os                         966 non-null    object
#  21  primary_camera_rear        980 non-null    float64
#  22  primary_camera_front       975 non-null    float64
#  23  extended_memory_available  980 non-null    int64
#  24  extended_upto              500 non-null    float64
# dtypes: bool(3), float64(12), int64(5), object(5)
# memory usage: 171.4+ KB

# %%
df.shape
# Out:
# (980, 25)

# %%
# check for duplicate rows in the data

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Missing Value Analysis

# %%
# check for missing values in the data

df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# resolution                     0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# dtype: int64

# %%
# columns with missing values

(
    df.isnull()
    .sum()
    .loc[lambda x: x > 0]
    .index
    .to_list()
)
# Out:
# ['rating',
#  'processor_brand',
#  'num_cores',
#  'processor_speed',
#  'battery_capacity',
#  'fast_charging',
#  'num_front_cameras',
#  'os',
#  'primary_camera_front',
#  'extended_upto']

# %%
# check % for missing values in columns with missing values 

(
    df.isnull()
    .sum()
    .loc[lambda x: x > 0] 
    .sort_values(ascending = False) / len(df) * 100
)
# Out:
# extended_upto           48.979592
# fast_charging           21.530612
# rating                  10.306122
# processor_speed          4.285714
# processor_brand          2.040816
# os                       1.428571
# battery_capacity         1.122449
# num_cores                0.612245
# primary_camera_front     0.510204
# num_front_cameras        0.408163
# dtype: float64

# %%
# number of rows in the data that have missing values

missing_rows = (
    df
    .isnull()
    .any(axis=1)
    .sum()
)

print(f'There are {missing_rows} rows with missing values in the data.')

print(f"It accounts for {(missing_rows/df.shape[0])*100:.2f}% of the data")
# Out:
# There are 628 rows with missing values in the data.
# It accounts for 64.08% of the data

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
# primary_camera_front v/s num_front_cameras for rows with values for primary_camera_front

(
    df
    .loc[df["primary_camera_front"].isna(), ["primary_camera_front", "num_front_cameras"]]
)
# Out:
#      primary_camera_front  num_front_cameras
# 69                    NaN                NaN
# 458                   NaN                NaN
# 599                   NaN                1.0
# 954                   NaN                NaN
# 972                   NaN                NaN

# %% [markdown]
# ### Observations - Missing Value Analysis
#
# - The dataset contains **980 rows** and **25 columns**.
# - There are **no duplicated rows** in the dataset.
# - Missing values are present in the following columns:
#   - **`rating`**
#   - **`processor_brand`**
#   - **`num_cores`**
#   - **`processor_speed`**
#   - **`battery_capacity`**
#   - **`fast_charging`**
#   - **`num_front_cameras`**
#   - **`os`**
#   - **`primary_camera_front`**
#   - **`extended_upto`**
# - In `extended_upto` column missing values are due to the smartphones not having extended memory feature.
# - In `fast_charging` column missing values are due to either there is no fast charging or fast charging wattage is not known.
# - In most of the rows `num_front_cameras` is missing due to primary_camera_front missing.

# %% [markdown]
# # Outlier Analysis

# %% [markdown]
# ## Price

# %%
outlier_overview(dataframe= df, column_name = "price")
# Out:
# count       980.000000
# mean      32520.504082
# std       39531.812669
# min        3499.000000
# 25%       12999.000000
# 50%       19994.500000
# 75%       35491.500000
# max      650000.000000
# Name: price, dtype: float64

# %%
sns.kdeplot(data = df, x = "price")
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
outliers_df = df.loc[
    df['price'] > (df['price'].quantile(0.75) + 1.5 * (df['price'].quantile(0.75) - df['price'].quantile(0.25)))
]

outliers_df.shape
# Out:
# (107, 25)

# %%
# export data in csv for better analysis

export_data(outliers_df, "outliers")
# Out:
# Data successfully exported to: E:\Learnings\Learning_curves\Mobile_insights\data\export\outliers.csv

# %% [markdown]
# ### Observations - Outliers Analysis
#
# - `Price` column has potential outliers.
# - Phones with prices greater than 200000 can be considered as outliers as they are luxury devices and cannot be represented by the features.

# %% [markdown]
# # Actions to be taken
#
# - Fill missing values in the extended_upto column with 0 where extended_memory_available = 0.
# - Remove smartphones with price > 200000.

# %%
analysis_df = prepare_segment_trends_data(df)

# %%
outlier_overview(dataframe= analysis_df, column_name = "price")
# Out:
# count       976.000000
# mean      31029.820697
# std       29870.079162
# min        3499.000000
# 25%       12999.000000
# 50%       19990.000000
# 75%       34999.000000
# max      199990.000000
# Name: price, dtype: float64

# %%
sns.kdeplot(data = analysis_df, x = "price")
# Out:
# <Axes: xlabel='price', ylabel='Density'>
